# %% [markdown]
# # Some notes on the final assignment
#
# #### Before start to read please run the following code

# %%
import pandas as pd

# %% [markdown]
# ##### 1. In questions 2 and 4, when I wanted to parse the pasrse the data I could not use the parser `html5lib` beacuse I got errors due to my system. So I use the `lxml` pasrser. The result is the same
# ##### 2. In question 2, in the section reated to extracting revenue and sort it in a adat frame I used `pd.read_csv()` to extract revenue as followis:

# %%
url='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm'
tesla_revenue=pd.DataFrame(columns=['Date', 'Revenue'])
tesla_pandas_read_html=pd.read_html(url)
type(tesla_pandas_read_html)
# Out:
# list

# %% [markdown]
# ##### the type of `tesla_pandas_read_html` is `list` and I cant print it as follows:

# %%
for i,element in enumerate(tesla_pandas_read_html):
    print(f'               The element {i} is \n')
    print('=============================================\n')
    print(element)
    print('============================================\n')
# Out:
#                The element 0 is
#
# ...
#
#     Tesla Annual Revenue (Millions of US $)  \
# 0                                      2021
# 1                                      2020
# 2                                      2019
# 3                                      2018
# 4                                      2017
# 5                                      2016
# 6                                      2015
# 7                                      2014
# 8                                      2013
# 9                                      2012
# 10                                     2011
# 11                                     2010
# 12                                     2009
#
#    Tesla Annual Revenue (Millions of US $).1
# 0                                    $53,823
# 1                                    $31,536
# 2                                    $24,578
# 3                                    $21,461
# 4                                    $11,759
# ...

# %% [markdown]
# ##### So the only element that is omportant is the second one in the `tesla_pandas_read_html`. i.e.

# %%
tesla_pandas_read_html[1]
# Out:
#    Tesla Quarterly Revenue (Millions of US $)  \
# 0                                  2022-09-30
# 1                                  2022-06-30
# 2                                  2022-03-31
# 3                                  2021-12-31
# 4                                  2021-09-30
# 5                                  2021-06-30
# 6                                  2021-03-31
# 7                                  2020-12-31
# 8                                  2020-09-30
# 9                                  2020-06-30
# 10                                 2020-03-31
# 11                                 2019-12-31
# 12                                 2019-09-30
# 13                                 2019-06-30
# 14                                 2019-03-31
# 15                                 2018-12-31
# 16                                 2018-09-30
# 17                                 2018-06-30
# 18                                 2018-03-31
# ...

# %% [markdown]
# ##### In order to sort is in our desired data frame I used the following code with is equvalent to locating all table based on prevoius lab.

# %%
read_tesla_data_html=pd.read_html(url)
for j in range(0,len(tesla_pandas_read_html[1].iloc[:,0])):
    date=tesla_pandas_read_html[1].iloc[j,0]
    #print(date)
    revenue=tesla_pandas_read_html[1].iloc[j,1]
    #print(revenue)
    new_data = pd.DataFrame([{'Date':date,'Revenue':revenue}])
    tesla_revenue=pd.concat([tesla_revenue, new_data], ignore_index=True)
tesla_revenue
# Out:
#           Date  Revenue
# 0   2022-09-30  $21,454
# 1   2022-06-30  $16,934
# 2   2022-03-31  $18,756
# 3   2021-12-31  $17,719
# 4   2021-09-30  $13,757
# 5   2021-06-30  $11,958
# 6   2021-03-31  $10,389
# 7   2020-12-31  $10,744
# 8   2020-09-30   $8,771
# 9   2020-06-30   $6,036
# 10  2020-03-31   $5,985
# 11  2019-12-31   $7,384
# 12  2019-09-30   $6,303
# 13  2019-06-30   $6,350
# 14  2019-03-31   $4,541
# 15  2018-12-31   $7,226
# 16  2018-09-30   $6,824
# 17  2018-06-30   $4,002
# 18  2018-03-31   $3,409
# 19  2017-12-31   $3,288
# 20  2017-09-30   $2,985
# 21  2017-06-30   $2,790
# 22  2017-03-31   $2,696
# 23  2016-12-31   $2,285
# 24  2016-09-30   $2,298
# 25  2016-06-30   $1,270
# 26  2016-03-31   $1,147
# 27  2015-12-31   $1,214
# 28  2015-09-30     $937
# 29  2015-06-30     $955
# 30  2015-03-31     $940
# 31  2014-12-31     $957
# 32  2014-09-30     $852
# 33  2014-06-30     $769
# 34  2014-03-31     $621
# 35  2013-12-31     $615
# 36  2013-09-30     $431
# ...

# %% [markdown]
# ##### The same procedure was deployed for answerign the question 4

# %% [markdown]
# ## Important note ##
# ### If we want to sort Tesla anual Revenue (Millions of US ), not only Tesla Quarterly Revenue (Millions of US ) we could use the folliwng code:

# %%
tesla_revenue1=pd.DataFrame(columns=['Date', 'Revenue'])

tesla_pandas_read_html1=pd.read_html(url)
for i in range(0,2):
    for j in range(0,len(tesla_pandas_read_html1[i].iloc[:,0])):
        date=tesla_pandas_read_html1[i].iloc[j,0]
        #print(date)
        revenue=tesla_pandas_read_html1[i].iloc[j,1]
        #print(revenue)
        new_data = pd.DataFrame([{'Date':date,'Revenue':revenue}])
        tesla_revenue1=pd.concat([tesla_revenue1, new_data], ignore_index=True)
tesla_revenue1
# Out:
#           Date  Revenue
# 0         2021  $53,823
# 1         2020  $31,536
# 2         2019  $24,578
# 3         2018  $21,461
# 4         2017  $11,759
# ..         ...      ...
# 62  2010-06-30      $28
# 63  2010-03-31      $21
# 64  2009-12-31      NaN
# 65  2009-09-30      $46
# 66  2009-06-30      $27
#
# [67 rows x 2 columns]

# %% [markdown]
# ## But in this case we weel get an error while we want to plot with `make_graph` fucntion . Beacuse in the `make_graph` function we have

# %%
stock_data_specific = stock_data[stock_data.Date <= '2021--06-14']
revenue_data_specific = revenue_data[revenue_data.Date <= '2021-04-30']

# %% [markdown]
# ## which means that it onmy read the 'Date' with the above format.
